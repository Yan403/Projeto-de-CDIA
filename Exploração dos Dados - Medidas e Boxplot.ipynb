# %%
import pandas as pd

games = pd.read_csv("C:/Users/yan_b/Desktop/android-games.csv")
games
# Out:
#       rank                                         title  total ratings  \
# 0        1                  Garena Free Fire - The Cobra       80678661
# 1        2                   PUBG MOBILE: Graffiti Prank       35971961
# 2        3                     Mobile Legends: Bang Bang       25836869
# 3        4                                   Brawl Stars       17181659
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14237554
# ...    ...                                           ...            ...
# 1725    96                     Piknik Słowo - Word Snack         122845
# 1726    97           Wordox – Free multiplayer word game         120476
# 1727    98                             4 Fotos 1 Palavra         114852
# 1728    99                 زوايا - لعبة ستحرك زوايا عقلك         110293
# 1729   100         Word Life - Connect crosswords puzzle         109809
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
print(games.mean())
# Out:
# rank                5.047572e+01
# total ratings       1.101182e+06
# average rating      4.313410e+00
# growth (30 days)    1.931673e+02
# growth (60 days)    3.969249e+00
# price               1.296532e-02
# 5 star ratings      7.883837e+05
# 4 star ratings      1.216466e+05
# 3 star ratings      5.954986e+04
# 2 star ratings      2.796247e+04
# 1 star ratings      1.036364e+05
# paid                4.046243e-03
# dtype: float64

# %%
print(games.median())
# Out:
# rank                    51.00
# total ratings       457675.00
# average rating           4.33
# growth (30 days)         0.50
# growth (60 days)         1.00
# price                    0.00
# 5 star ratings      310943.50
# 4 star ratings       54643.50
# 3 star ratings       26658.50
# 2 star ratings       11330.50
# 1 star ratings       35694.00
# paid                     0.00
# dtype: float64

# %%
print(games.var())
# Out:
# rank                8.376180e+02
# total ratings       1.096761e+13
# average rating      6.428518e-02
# growth (30 days)    2.280652e+07
# growth (60 days)    3.576979e+02
# price               5.928854e-02
# 5 star ratings      6.165592e+12
# 4 star ratings      8.736168e+10
# 3 star ratings      2.094968e+10
# 2 star ratings      5.893057e+09
# 1 star ratings      1.288716e+11
# paid                4.032201e-03
# dtype: float64

# %%
games.std()
# Out:
# rank                2.894163e+01
# total ratings       3.311738e+06
# average rating      2.535452e-01
# growth (30 days)    4.775618e+03
# growth (60 days)    1.891290e+01
# price               2.434924e-01
# 5 star ratings      2.483061e+06
# 4 star ratings      2.955701e+05
# 3 star ratings      1.447400e+05
# 2 star ratings      7.676625e+04
# 1 star ratings      3.589869e+05
# paid                6.349962e-02
# dtype: float64

# %%
games.describe()
# Out:
#               rank  total ratings  average rating  growth (30 days)  \
# count  1730.000000   1.730000e+03     1730.000000       1730.000000
# mean     50.475723   1.101182e+06        4.313410        193.167341
# std      28.941630   3.311738e+06        0.253545       4775.617650
# min       1.000000   3.823800e+04        3.090000          0.000000
# 25%      25.000000   1.879988e+05        4.180000          0.100000
# 50%      51.000000   4.576750e+05        4.330000          0.500000
# 75%      75.750000   9.443342e+05        4.490000          1.600000
# max     100.000000   8.067866e+07        4.910000     140394.400000
#
#        growth (60 days)        price  5 star ratings  4 star ratings  \
# count       1730.000000  1730.000000    1.730000e+03    1.730000e+03
# mean           3.969249     0.012965    7.883837e+05    1.216466e+05
# std           18.912904     0.243492    2.483061e+06    2.955701e+05
# min            0.000000     0.000000    2.189800e+04    2.441000e+03
# ...

# %%
games.boxplot(column=["1 star ratings","2 star ratings",  "3 star ratings", "4 star ratings"])
# Out:
# <AxesSubplot:>

# %%
games.boxplot(column=["5 star ratings", "price", "paid"])
# Out:
# <AxesSubplot:>

# %%
games.boxplot(column=["rank", "total ratings", "growth (30 days)", "growth (60 days)"])
# Out:
# <AxesSubplot:>
